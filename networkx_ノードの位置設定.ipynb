# %%
import networkx as nx
G = nx.DiGraph()
nodes = [
    
]
G.add_nodes_from([0, 5])
edges = [
    (0, 1),
    (0, 2),
    (0, 3),
    (3, 4)
]
G.add_edges_from(edges)
remove_list = []
for edge in edges:
    judge = local_node_connectivity(G, edge[0], edge[1])
    if judge != 1:
        remove_list.append(edge)
for route in remove_list:
    edges.remove(route)
print("edges after removed")
print(edges)

print(G)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 7>()
#       5 G = nx.DiGraph()
#       6 G.add_nodes_from([0, 25])
# ----> 7 G.add_edges_from(edges)
#       8 print(G)
#      10 #枝削除
#
# NameError: name 'edges' is not defined

# %%
from matplotlib import pyplot as plt #matplotlibのインポート
pos = nx.circular_layout(G)
pos = {
    0: (-1, 1),
    3: (-1, 0.9),
    1: (-0.9, 1),
    6: (-0.9, 0.9),
    7: (-0.9, 0.8),
    17:(-0.9, 0.7),
    12:(-0.9, 0.6),
    14:(-0.9, 0.5),
    16:(-0.8, 1),
    8:(-0.8, 0.9),
    19:(-0.8, 0.8),
    2:(-0.8, 0.7),
    4:(-0.7, 1),
    9:(-0.7, 0.9),
    23:(-0.7,0.8),
    15:(-0.7,0.7),
    11:(-0.6, 1),
    18:(-0.6, 0.9),
    22:(-0.6, 0.8),
    24:(-0.6, 0.7),
    5:(-0.65, 0.34),
    10:(-0.68, 0.25),
    13:(-0.82, 0.32),
    20:(-0.75, 0.26),
    21:(-0.85, 0.33),
    25:(-0.93, 0.27)
}


# グラフの描画
plt.figure(figsize=(10,10)) #グラフエリアのサイズ
nx.draw(G,pos = pos, arrows = True, arrowsize=20, with_labels = True)
